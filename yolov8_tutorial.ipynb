# %% [markdown]
# <a href="https://colab.research.google.com/github/ulsanether/noba/blob/main/yolov8_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov8" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#
# <br>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov8"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# <br>
#
# Welcome to the Ultralytics YOLOv8 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLOv8</a> is the latest version of the YOLO (You Only Look Once) object detection and image segmentation model developed by <a href="https://ultralytics.com">Ultralytics</a>. This notebook serves as the starting point for exploring the various resources available to help you get started with YOLOv8 and understand its features and capabilities.
#
# The YOLOv8 models are designed to be fast, accurate, and easy to use, making them an excellent choice for a wide range of object detection and image segmentation tasks. They can be trained on large datasets and are capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# Whether you are a seasoned machine learning practitioner or new to the field, we hope that the resources in this notebook will help you get the most out of YOLOv8. Please feel free to browse the <a href="https://docs.ultralytics.com/">YOLOv8 Docs</a> and reach out to us with any questions or feedback.
#
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.58 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.6/78.2 GB disk)

# %% [markdown]
# # 1. Predict
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) in the YOLOv8 [Docs](https://docs.ultralytics.com).

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# !yolo predict model=yolov8n.pt source='https://upload.wikimedia.org/wikipedia/commons/thumb/1/1e/0_Hyundai_Mega_Truck.jpg/1200px-0_Hyundai_Mega_Truck.jpg' save_crop=True
# !yolo predict model=yolov8n.pt source='https://itruck-image-server.s3.ap-northeast-2.amazonaws.com/tb_mycar_mcr_img/46816_1_20230314145242.png' save_crop=True
# !yolo predict model=yolov8n.pt source='https://ifh.cc/g/3Pamjq.jpg' save_crop=True
# !yolo predict model=yolov8n.pt source='https://ifh.cc/g/tqPwOj.png' save_crop=True
# Out:
# Ultralytics YOLOv8.0.54 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://ifh.cc/g/3Pamjq.jpg locally at 3Pamjq.jpg
# image 1/1 /content/3Pamjq.jpg: 384x640 1 person, 8 cars, 1 truck, 1 boat, 22.7ms
# Speed: 0.8ms preprocess, 22.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %% [markdown]
# # **비디오에서 frame 이미지 추출**
# 굵은 텍스트굵은 텍스트조건
# - truck이 존재하는 이미지만 따로 저장
# - 이미지에 트럭이 존재하는 위치에 네모박스를 표시해서 저장하기

# %%
import cv2
import os

import torch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
vidcap = cv2.VideoCapture("/content/drive/MyDrive/노바투스2023/09000101_0100.mp4")

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

# %%
results = model('https://ifh.cc/g/3Pamjq.jpg')
# Out:
# Found https://ifh.cc/g/3Pamjq.jpg locally at 3Pamjq.jpg
# image 1/1 /content/3Pamjq.jpg: 384x640 1 person, 8 cars, 1 truck, 1 boat, 26.4ms
# Speed: 0.7ms preprocess, 26.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
pred_class = results[0].boxes.data[:, 5]

# %%
8 in pred_class
# Out:
# True

# %%
# results[0].names
results[0].boxes.data
# Out:
# tensor([[1.10911e+03, 2.50285e+01, 1.20284e+03, 5.82870e+01, 6.53935e-01, 2.00000e+00],
#         [1.37815e+03, 2.86651e+01, 1.47582e+03, 5.97693e+01, 5.43384e-01, 2.00000e+00],
#         [9.23851e+02, 1.81073e+01, 1.02832e+03, 5.33152e+01, 4.58090e-01, 2.00000e+00],
#         [7.67634e+02, 7.34325e+01, 8.04732e+02, 1.66484e+02, 3.78683e-01, 0.00000e+00],
#         [8.04506e+02, 8.13991e+01, 8.42210e+02, 1.59298e+02, 3.59265e-01, 0.00000e+00],
#         [1.23909e+03, 2.53792e+01, 1.32714e+03, 5.81387e+01, 3.57573e-01, 2.00000e+00],
#         [8.10248e+02, 8.01972e+01, 8.41345e+02, 1.38618e+02, 3.44654e-01, 0.00000e+00],
#         [9.17981e+02, 9.49335e+01, 9.42141e+02, 1.47110e+02, 3.24531e-01, 0.00000e+00],
#         [1.63646e+03, 3.14165e+01, 1.72401e+03, 6.43903e+01, 2.96488e-01, 2.00000e+00],
#         [1.51289e+03, 2.21226e+01, 1.62373e+03, 6.17586e+01, 2.76616e-01, 2.00000e+00],
# ...

# %%
tensor_to_int = lambda x:int(x.detach().cpu().numpy())

# %%
vidcap = cv2.VideoCapture("/content/drive/MyDrive/노바투스2023/09000101_0100.mp4")
success,image = vidcap.read()
count = 6000
os.makedirs("/content/drive/MyDrive/노바투스2023/images/", exist_ok=True)
frame_seq = 6000
vidcap.set(1,frame_seq)

while success:
    success,image = vidcap.read()
    if 6000 <= count <= 7500:
        cv2.imwrite("/content/drive/MyDrive/노바투스2023/images/frame%05d.jpg" % count, image)
    # print('Read a new frame: ', success)
    count += 1
    if count == 7500:
        break

# %%
vidcap = cv2.VideoCapture("/content/drive/MyDrive/노바투스2023/09000101_0100.mp4")
success,image = vidcap.read()
count = 0
os.makedirs("/content/drive/MyDrive/노바투스2023/images_filter/", exist_ok=True)
ROI = (0, 0, 1920//2, 1080//3)
ROI_area = (ROI[2]-ROI[0])*(ROI[3]-ROI[1])
while success:
    success,image = vidcap.read()
    results = model(image)
    pred_data = results[0].boxes.data
    pred_class = pred_data[:, 5]
    pred_boxes = pred_data[:, :4]
    is_save = False
    if 7 in pred_class:
        truck_idicies = torch.where(pred_class==7)[0]
        for truck_idx in truck_idicies:
            lt_x, lt_y, rb_x, rb_y = pred_boxes[truck_idx]
            lt_x, lt_y, rb_x, rb_y = map(tensor_to_int, [lt_x, lt_y, rb_x, rb_y])
            box_area = (rb_x-lt_x)*(rb_y-lt_y)
            x1 = max(ROI[0], lt_x)
            y1 = max(ROI[1], lt_y)
            x2 = min(ROI[2], rb_x)
            y2 = min(ROI[3], rb_y)
            intersection_area = max(0, x2-x1)*max(0, y2-y1)
            iou = intersection_area/box_area
            if iou > 0.9:
                is_save = True
                cv2.rectangle(image, (lt_x, lt_y), (rb_x, rb_y), (255, 0, 0), 5)
        if is_save:
            cv2.rectangle(image, (ROI[0], ROI[1]), (ROI[2], ROI[3]), (0, 0, 255), 5)
            cv2.imwrite("/content/drive/MyDrive/노바투스2023/images_filter/frame%05d.jpg" % count, image)
    print('Read a new frame: ', success)
    count += 1
    if count == 7500:
        break
# Out:
# 0: 384x640 4 persons, 6 cars, 25.1ms
# Speed: 1.0ms preprocess, 25.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 6 cars, 13.6ms
# Speed: 0.5ms preprocess, 13.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 6 cars, 17.1ms
# Speed: 0.5ms preprocess, 17.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 6 cars, 12.5ms
# Speed: 0.5ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 6 cars, 12.7ms
# Speed: 0.5ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# 0: 384x640 4 persons, 6 cars, 14.9ms
# Speed: 0.5ms preprocess, 14.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# ...

# %%
# import shutil
# shutil.rmtree('/content/drive/MyDrive/노바투스2023/images/')

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://cocodataset.org/#home) dataset's `val` or `test` splits. The latest YOLOv8 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used.

# %%
# Download COCO val
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip

# %%
# Validate YOLOv8n on COCO128 val
# !yolo val model=yolov8n.pt data=coco128.yaml
# Out:
# Ultralytics YOLOv8.0.24 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Dataset 'coco128.yaml' not found ⚠️, missing paths ['/content/datasets/coco128/images/train2017']
# ...
# 100% 6.66M/6.66M [00:00<00:00, 50.5MB/s]
# Unzipping /content/datasets/coco128.zip...
# Dataset download success ✅ (0.5s), saved to /content/datasets
#
# ...
# 100% 755k/755k [00:00<00:00, 99.8MB/s]
# val: Scanning /content/datasets/coco128/labels/train2017... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<00:00, 1290.29it/s]
# val: New cache created: /content/datasets/coco128/labels/train2017.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:06<00:00,  1.22it/s]
#                    all        128        929       0.64      0.537      0.605      0.446
#                 person        128        254      0.797      0.677      0.764      0.538
# ...

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLOv8 on [Detection](https://docs.ultralytics.com/tasks/detect/), [Segmentation](https://docs.ultralytics.com/tasks/segment/) and [Classification](https://docs.ultralytics.com/tasks/classify/) datasets.

# %%
# Train YOLOv8n on COCO128 for 3 epochs
# !yolo train model=yolov8n.pt data=coco128.yaml epochs=3 imgsz=640
# Out:
# Ultralytics YOLOv8.0.24 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %% [markdown]
# # 4. Export
#
# Export a YOLOv8 model to any supported format with the `format` argument, i.e. `format=onnx`.
#
# - 💡 ProTip: Export to [ONNX](https://onnx.ai/) or [OpenVINO](https://docs.openvino.ai/latest/index.html) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://developer.nvidia.com/tensorrt) for up to 5x GPU speedup.
#
#
# | Format                                                                     | `format=`          | Model                     |
# |----------------------------------------------------------------------------|--------------------|---------------------------|
# | [PyTorch](https://pytorch.org/)                                            | -                  | `yolov8n.pt`              |
# | [TorchScript](https://pytorch.org/docs/stable/jit.html)                    | `torchscript`      | `yolov8n.torchscript`     |
# | [ONNX](https://onnx.ai/)                                                   | `onnx`             | `yolov8n.onnx`            |
# | [OpenVINO](https://docs.openvino.ai/latest/index.html)                     | `openvino`         | `yolov8n_openvino_model/` |
# | [TensorRT](https://developer.nvidia.com/tensorrt)                          | `engine`           | `yolov8n.engine`          |
# | [CoreML](https://github.com/apple/coremltools)                             | `coreml`           | `yolov8n.mlmodel`         |
# | [TensorFlow SavedModel](https://www.tensorflow.org/guide/saved_model)      | `saved_model`      | `yolov8n_saved_model/`    |
# | [TensorFlow GraphDef](https://www.tensorflow.org/api_docs/python/tf/Graph) | `pb`               | `yolov8n.pb`              |
# | [TensorFlow Lite](https://www.tensorflow.org/lite)                         | `tflite`           | `yolov8n.tflite`          |
# | [TensorFlow Edge TPU](https://coral.ai/docs/edgetpu/models-intro/)         | `edgetpu`          | `yolov8n_edgetpu.tflite`  |
# | [TensorFlow.js](https://www.tensorflow.org/js)                             | `tfjs`             | `yolov8n_web_model/`      |
# | [PaddlePaddle](https://github.com/PaddlePaddle)                            | `paddle`           | `yolov8n_paddle_model/`   |

# %%
# !yolo export model=yolov8n.pt format=torchscript
# Out:
# Ultralytics YOLOv8.0.24 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from yolov8n.pt with output shape (1, 84, 8400) (6.2 MB)
#
# TorchScript: starting export with torch 1.13.1+cu116...
# TorchScript: export success ✅ 1.7s, saved as yolov8n.torchscript (12.4 MB)
#
# Export complete (2.2s)
# Results saved to /content
# Predict:         yolo task=detect mode=predict model=yolov8n.torchscript -WARNING ⚠️ not yet supported for YOLOv8 exported models
# Validate:        yolo task=detect mode=val model=yolov8n.torchscript -WARNING ⚠️ not yet supported for YOLOv8 exported models
# Visualize:       https://netron.app

# %% [markdown]
# # 5. Python Usage
#
# YOLOv8 was reimagined using Python-first principles for the most seamless Python YOLO experience yet. YOLOv8 models can be loaded from a trained checkpoint or created from scratch. Then methods are used to train, val, predict, and export the model. See a detailed Python usage examples in the YOLOv8 [Docs](https://docs.ultralytics.com/usage/python/).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='coco128.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
success = model.export(format='onnx')  # export the model to ONNX format

# %% [markdown]
# # 6. Tasks
#
# YOLOv8 can train, val, predict and export models for the 3 primary tasks in vision AI: detection, segmentation and classification.
#
# <img width="1024" src="https://user-images.githubusercontent.com/26833433/212094133-6bb8c21c-3d47-41df-a512-81c5931054ae.png">

# %% [markdown]
# ## 1. Detection
#
# YOLOv8 _detection_ models have no suffix and are the default YOLOv8 models, i.e. `yolov8n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detect/) for full details.

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='coco128.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 2. Segmentation
#
# YOLOv8 _segmentation_ models use the `-seg` suffix, i.e. `yolov8n-seg.pt` and are pretrained on COCO. See [Segmentation Docs](https://docs.ultralytics.com/tasks/segment/) for full details.

# %%
# Load YOLOv8n-seg, train it on COCO128-seg for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')  # load a pretrained YOLOv8n segmentation model
model.train(data='coco128-seg.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 3. Classification
#
# YOLOv8 _classification_ models use the `-cls` suffix, i.e. `yolov8n-cls.pt` and are pretrained on ImageNet. See [Classification Docs](https://docs.ultralytics.com/tasks/classify/) for full details.

# %%
# Load YOLOv8n-cls, train it on mnist160 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')  # load a pretrained YOLOv8n classification model
model.train(data='mnist160', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# Git clone install (for development)
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 6657, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 6657 (delta 95), reused 80 (delta 37), pack-reused 6474
# Receiving objects: 100% (6657/6657), 4.86 MiB | 16.82 MiB/s, done.
# Resolving deltas: 100% (4544/4544), done.
#   Preparing metadata (setup.py) ... done

# %%
# Run YOLOv8 tests (git clone install only)
# !pytest ultralytics/tests
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.16, pytest-3.6.4, py-1.11.0, pluggy-0.7.1
# rootdir: /content/ultralytics, inifile: setup.cfg
# collected 40 items
#
# ultralytics/tests/test_cli.py .......
#
# ========================== slowest 25 test durations ===========================
# 22.23s call     tests/test_cli.py::test_train_det
# 20.21s call     tests/test_cli.py::test_train_seg
# 14.47s call     tests/test_cli.py::test_val_segment
# 13.15s call     tests/test_cli.py::test_special_modes
# 12.47s call     tests/test_cli.py::test_val_classify
# 11.46s call     tests/test_cli.py::test_val_detect
# 8.96s call     tests/test_cli.py::test_train_cls
# 0.00s teardown tests/test_cli.py::test_special_modes
# 0.00s teardown tests/test_cli.py::test_train_det
# 0.00s teardown tests/test_cli.py::test_val_detect
# 0.00s teardown tests/test_cli.py::test_train_seg
# 0.00s teardown tests/test_cli.py::test_train_cls
# ...

# %%
# Validate multiple models
for x in 'nsmlx':
  # !yolo val model=yolov8{x}.pt data=coco.yaml
# Out:
# Ultralytics YOLOv8.0.53 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Dataset 'coco.yaml' images not found ⚠️, missing paths ['/content/datasets/coco/val2017.txt']
# ...
# 100% 169M/169M [00:01<00:00, 170MB/s]
# Unzipping /content/datasets/coco2017labels-segments.zip to /content/datasets...
# Traceback (most recent call last):
#   File "/content/ultralytics/ultralytics/yolo/utils/downloads.py", line 48, in unzip_file
#     zipObj.extract(f, path=path)
#   File "/usr/lib/python3.9/zipfile.py", line 1625, in extract
#     return self._extract_member(member, path, pwd)
#   File "/usr/lib/python3.9/zipfile.py", line 1695, in _extract_member
#     with self.open(member, pwd=pwd) as source, \
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 33, in <module>
# ...
